# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import scipy.stats
import pickle
from sklearn.linear_model import LinearRegression

# %%
dpi = 200

plt.rcParams.update({
    'xtick.labelsize': 24,
    'ytick.labelsize': 24,
    'axes.labelsize': 28,
    'figure.dpi': dpi,
    'axes.grid': True,
    'grid.linestyle': '--',
    'figure.figsize':(16,10),
    'axes.titlesize':24
})

# %% [markdown]
# # SI-Fig3

# %%
# Orbital occupation numbers from DMRG calculation for H32 chain
# for N, N-1 and N+1 states respectively

list1 = [1.62654961, 1.62654972, 1.71297056, 1.71443376, 1.72769743, 1.78679822,
         1.71431161, 1.78679833, 1.71443371, 1.71282887, 1.71297056, 1.7128289,
         1.71256401, 1.71256405, 1.72769728, 1.71431161, 0.37489675, 0.37489661,
         0.28743604, 0.28703045, 0.2123627, 0.21236275, 0.28716843, 0.28560916,
         0.28548653, 0.28548655, 0.28560917, 0.28716843, 0.27185581, 0.27185594,
         0.2870304, 0.28743604]

list2 = [1.62951523, 1.62949563, 1.72115931, 1.72238619, 1.73608146, 1.80395387,
         1.7221876, 1.80394601, 1.72236152, 1.72095846, 1.72116819, 1.72098077,
         1.72062341, 1.72061271, 1.73609995, 1.72221662, 0.26464945, 0.26464486,
         0.21566118, 0.2155366, 0.1770705, 0.17707075, 0.21558113, 0.21432275,
         0.21430173, 0.21429785, 0.21431476, 0.2155859, 0.20589613, 0.20589898,
         0.21553375, 0.21566577]

list3 = [1.74941774, 1.74940812, 1.7928927, 1.79402034, 1.80148382, 1.82666661,
         1.79399628, 1.82665657, 1.79400337, 1.79285539, 1.79288785, 1.79284161,
         1.79278337, 1.7927838, 1.80147443, 1.79399745, 0.36186163, 0.36186433,
         0.27094462, 0.27040074, 0.18819196, 0.1881932, 0.27059929, 0.26931404,
         0.26913706, 0.26915954, 0.2693247, 0.27058104, 0.25535227, 0.25534846,
         0.27040707, 0.27094188]

list1 = sorted(list1, reverse=True)
list2 = sorted(list2,reverse=True)
list3 = sorted(list3,reverse=True)

plt.figure()
plt.plot(range(len(list1)), list1, marker='o', markersize=10, linestyle='-', label="$N$ State")
plt.plot(range(len(list2)), list2, marker='o', markersize=10, linestyle='-', label="$N-1$ State")
plt.plot(range(len(list3)), list3, marker='o', markersize=10, linestyle='-', label="$N+1$ State")

# Formatting
plt.xticks(fontsize=24)
plt.yticks(fontsize=24)
plt.xlabel("Orbital Index", fontsize=24)
plt.ylabel("Orbital Occupation", fontsize=24)
plt.title(r"Active space orbital occupancy for the H$_{32}$ system",fontsize=32)
plt.ylim(-0.3, 2.3)
plt.legend(fontsize=24, loc='best')
plt.grid(True, linestyle='--', alpha=0.6)
plt.tight_layout()
plt.savefig('DMRGoccAna.png', dpi=dpi)
